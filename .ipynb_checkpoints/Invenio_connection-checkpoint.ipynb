# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\reema\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\reema\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\reema\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\reema\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\reema\anaconda3\lib\site-packages (from requests) (2023.7.22)

# %%
import requests

# Base URL of your Invenio instance
base_url = "https://127.0.0.1:5000"

# Disable SSL warnings (useful for self-signed certificates)
requests.packages.urllib3.disable_warnings()

# Example API endpoint (replace with your actual endpoint)
endpoint = f"{base_url}/api/records"

# Optional: Authentication (use access token if authentication is enabled)
# token = "your_access_token"
# headers = {"Authorization": f"Bearer {token}"}

# Make a GET request
response = requests.get(endpoint, verify=False)  # `verify=False` to bypass SSL verification

# Check the response
if response.status_code == 200:
    print("Success!")
    print(response.json())  # Parse and print the JSON response
else:
    print(f"Failed to connect. Status code: {response.status_code}")
    print(response.text)
# Out:
# Success!
# {'hits': {'hits': [{'id': 'mj154-z9j55', 'created': '2025-01-19T15:30:03.367594+00:00', 'updated': '2025-01-19T15:30:03.596920+00:00', 'links': {'self': 'https://127.0.0.1:5000/api/records/mj154-z9j55', 'self_html': 'https://127.0.0.1:5000/records/mj154-z9j55', 'parent': 'https://127.0.0.1:5000/api/records/azxmd-8wy09', 'parent_html': 'https://127.0.0.1:5000/records/azxmd-8wy09', 'self_iiif_manifest': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/manifest', 'self_iiif_sequence': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/sequence/default', 'files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files', 'media_files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files', 'archive': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files-archive', 'archive_media': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files-archive', 'latest': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions/latest', 'latest_html': 'https://127.0.0.1:5000/records/mj154-z9j55/latest', 'draft': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft', 'versions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions', 'access_links': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/links', 'access_grants': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/grants', 'access_users': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/users', 'access_groups': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/groups', 'access_request': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/request', 'access': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access', 'reserve_doi': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft/pids/doi', 'communities': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities', 'communities-suggestions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities-suggestions', 'requests': 'https://127.0.0.1:5000/api/records/mj154-z9j55/requests'}, 'revision_id': 3, 'parent': {'id': 'azxmd-8wy09', 'access': {'owned_by': {'user': '2'}, 'settings': {'allow_user_requests': False, 'allow_guest_requests': False, 'accept_conditions_text': None, 'secret_link_expiration': 0}}, 'communities': {}, 'pids': {}}, 'versions': {'is_latest': True, 'index': 1}, 'is_published': True, 'is_draft': False, 'pids': {'oai': {'identifier': 'oai:my-site.com:mj154-z9j55', 'provider': 'oai'}}, 'metadata': {'resource_type': {'id': 'image', 'title': {'de': 'Bild', 'en': 'Image', 'sv': 'Bild'}}, 'creators': [{'person_or_org': {'type': 'personal', 'name': 'Patel, Thomas', 'given_name': 'Thomas', 'family_name': 'Patel', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Jones, Carla', 'given_name': 'Carla', 'family_name': 'Jones', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'contactperson', 'title': {'de': 'Kontaktperson', 'en': 'Contact person', 'sv': 'Kontaktperson'}}}, {'person_or_org': {'type': 'personal', 'name': 'Pierce, Christopher', 'given_name': 'Christopher', 'family_name': 'Pierce', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Martinez, Michael', 'given_name': 'Michael', 'family_name': 'Martinez', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'datacollector', 'title': {'de': 'DatensammlerIn', 'en': 'Data collector', 'sv': 'Datainsamlare'}}}], 'title': "Stevenson-Jenkins's gallery", 'additional_titles': [{'title': 'a research data management platform', 'type': {'id': 'alternative-title', 'title': {'de': 'Alternativer Titel', 'en': 'Alternative title', 'sv': 'Alternativ titel'}}, 'lang': {'id': 'eng', 'title': {'en': 'English'}}}, {'title': "Smith-Contreras's gallery", 'type': {'id': ...

# %% [markdown]
# test connection 2( just extra)

# %%
import requests

# Base URL of your Invenio instance
base_url = "https://127.0.0.1:5000"

# Test API endpoint (public)
endpoint = f"{base_url}/api/records"

# Your access token (replace with your actual token)
access_token = "j66RscNftV77c28t3eNidKkkKPPQpgsLnXLcPXEHoPGxoD8FTxwtBcMFc0fC"

# Suppress SSL verification warnings (use only in testing)
requests.packages.urllib3.disable_warnings()

# Headers including the Authorization Bearer token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Make a GET request with the access token
response = requests.get(endpoint, headers=headers, verify=False)

if response.status_code == 200:
    print("Connection successful!")
    print(endpoint)
    print(response.json())
else:
    
    print(f"Connection failed. Status code: {response.status_code}")
    print(endpoint)
    print(response.text)
# Out:
# Connection successful!
# https://127.0.0.1:5000/api/records
# {'hits': {'hits': [{'id': 'mj154-z9j55', 'created': '2025-01-19T15:30:03.367594+00:00', 'updated': '2025-01-19T15:30:03.596920+00:00', 'links': {'self': 'https://127.0.0.1:5000/api/records/mj154-z9j55', 'self_html': 'https://127.0.0.1:5000/records/mj154-z9j55', 'parent': 'https://127.0.0.1:5000/api/records/azxmd-8wy09', 'parent_html': 'https://127.0.0.1:5000/records/azxmd-8wy09', 'self_iiif_manifest': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/manifest', 'self_iiif_sequence': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/sequence/default', 'files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files', 'media_files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files', 'archive': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files-archive', 'archive_media': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files-archive', 'latest': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions/latest', 'latest_html': 'https://127.0.0.1:5000/records/mj154-z9j55/latest', 'draft': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft', 'versions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions', 'access_links': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/links', 'access_grants': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/grants', 'access_users': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/users', 'access_groups': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/groups', 'access_request': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/request', 'access': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access', 'reserve_doi': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft/pids/doi', 'communities': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities', 'communities-suggestions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities-suggestions', 'requests': 'https://127.0.0.1:5000/api/records/mj154-z9j55/requests'}, 'revision_id': 3, 'parent': {'id': 'azxmd-8wy09', 'access': {'owned_by': {'user': '2'}, 'settings': {'allow_user_requests': False, 'allow_guest_requests': False, 'accept_conditions_text': None, 'secret_link_expiration': 0}}, 'communities': {}, 'pids': {}}, 'versions': {'is_latest': True, 'index': 1}, 'is_published': True, 'is_draft': False, 'pids': {'oai': {'identifier': 'oai:my-site.com:mj154-z9j55', 'provider': 'oai'}}, 'metadata': {'resource_type': {'id': 'image', 'title': {'de': 'Bild', 'en': 'Image', 'sv': 'Bild'}}, 'creators': [{'person_or_org': {'type': 'personal', 'name': 'Patel, Thomas', 'given_name': 'Thomas', 'family_name': 'Patel', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Jones, Carla', 'given_name': 'Carla', 'family_name': 'Jones', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'contactperson', 'title': {'de': 'Kontaktperson', 'en': 'Contact person', 'sv': 'Kontaktperson'}}}, {'person_or_org': {'type': 'personal', 'name': 'Pierce, Christopher', 'given_name': 'Christopher', 'family_name': 'Pierce', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Martinez, Michael', 'given_name': 'Michael', 'family_name': 'Martinez', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'datacollector', 'title': {'de': 'DatensammlerIn', 'en': 'Data collector', 'sv': 'Datainsamlare'}}}], 'title': "Stevenson-Jenkins's gallery", 'additional_titles': [{'title': 'a research data management platform', 'type': {'id': 'alternative-title', 'title': {'de': 'Alternativer Titel', 'en': 'Alternative title', 'sv': 'Alternativ titel'}}, 'lang': {'id': 'eng', 'title': {'en': 'English'}}}, {'title': "Smith-Contreras's gallery", 'type': {'id': ...

# %% [markdown]
# meta data retrieval:

# %%
# Example endpoint for fetching records
records_endpoint = f"{base_url}/api/records"

# Fetch records
response = requests.get(records_endpoint, verify=False)

if response.status_code == 200:
    records = response.json()
    print("Fetched records successfully!")
    print(records)
else:
    print(f"Failed to fetch records. Status code: {response.status_code}")
    print(response.text)
# Out:
# Fetched records successfully!
# {'hits': {'hits': [{'id': 'mj154-z9j55', 'created': '2025-01-19T15:30:03.367594+00:00', 'updated': '2025-01-19T15:30:03.596920+00:00', 'links': {'self': 'https://127.0.0.1:5000/api/records/mj154-z9j55', 'self_html': 'https://127.0.0.1:5000/records/mj154-z9j55', 'parent': 'https://127.0.0.1:5000/api/records/azxmd-8wy09', 'parent_html': 'https://127.0.0.1:5000/records/azxmd-8wy09', 'self_iiif_manifest': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/manifest', 'self_iiif_sequence': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/sequence/default', 'files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files', 'media_files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files', 'archive': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files-archive', 'archive_media': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files-archive', 'latest': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions/latest', 'latest_html': 'https://127.0.0.1:5000/records/mj154-z9j55/latest', 'draft': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft', 'versions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions', 'access_links': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/links', 'access_grants': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/grants', 'access_users': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/users', 'access_groups': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/groups', 'access_request': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/request', 'access': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access', 'reserve_doi': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft/pids/doi', 'communities': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities', 'communities-suggestions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities-suggestions', 'requests': 'https://127.0.0.1:5000/api/records/mj154-z9j55/requests'}, 'revision_id': 3, 'parent': {'id': 'azxmd-8wy09', 'access': {'owned_by': {'user': '2'}, 'settings': {'allow_user_requests': False, 'allow_guest_requests': False, 'accept_conditions_text': None, 'secret_link_expiration': 0}}, 'communities': {}, 'pids': {}}, 'versions': {'is_latest': True, 'index': 1}, 'is_published': True, 'is_draft': False, 'pids': {'oai': {'identifier': 'oai:my-site.com:mj154-z9j55', 'provider': 'oai'}}, 'metadata': {'resource_type': {'id': 'image', 'title': {'de': 'Bild', 'en': 'Image', 'sv': 'Bild'}}, 'creators': [{'person_or_org': {'type': 'personal', 'name': 'Patel, Thomas', 'given_name': 'Thomas', 'family_name': 'Patel', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Jones, Carla', 'given_name': 'Carla', 'family_name': 'Jones', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'contactperson', 'title': {'de': 'Kontaktperson', 'en': 'Contact person', 'sv': 'Kontaktperson'}}}, {'person_or_org': {'type': 'personal', 'name': 'Pierce, Christopher', 'given_name': 'Christopher', 'family_name': 'Pierce', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Martinez, Michael', 'given_name': 'Michael', 'family_name': 'Martinez', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'datacollector', 'title': {'de': 'DatensammlerIn', 'en': 'Data collector', 'sv': 'Datainsamlare'}}}], 'title': "Stevenson-Jenkins's gallery", 'additional_titles': [{'title': 'a research data management platform', 'type': {'id': 'alternative-title', 'title': {'de': 'Alternativer Titel', 'en': 'Alternative title', 'sv': 'Alternativ titel'}}, 'lang': {'id': 'eng', 'title': {'en': 'English'}}}, {'title': "Smith-Contreras's gallery", 'type': {'id': ...

# %% [markdown]
#  Fetch Metadata in a Specific Format (like Croissant)

# %%
import requests

# Base URL of your Invenio instance
base_url = "https://127.0.0.1:5000"

# Specify the API endpoint (e.g., fetch all records or a specific record)
records_endpoint = f"{base_url}/api/records"

# Access token (replace with your actual token)
access_token = "j66RscNftV77c28t3eNidKkkKPPQpgsLnXLcPXEHoPGxoD8FTxwtBcMFc0fC"

# Specify the Accept header to request JSON format (or any other supported format)
headers = {
    "Authorization": f"Bearer {access_token}",
    "Accept": "application/json",  # Use a supported format (e.g., application/json)
    "Content-Type": "application/json"
}

# Make a GET request to fetch records in JSON format
response = requests.get(records_endpoint, headers=headers, verify=False)

if response.status_code == 200:
    print("Fetched metadata in JSON format:")
    print(response.json())  # Process the response JSON data
else:
    print(f"Failed to fetch metadata. Status code: {response.status_code}")
    print(response.text)
# Out:
# Fetched metadata in JSON format:
# {'hits': {'hits': [{'id': 'mj154-z9j55', 'created': '2025-01-19T15:30:03.367594+00:00', 'updated': '2025-01-19T15:30:03.596920+00:00', 'links': {'self': 'https://127.0.0.1:5000/api/records/mj154-z9j55', 'self_html': 'https://127.0.0.1:5000/records/mj154-z9j55', 'parent': 'https://127.0.0.1:5000/api/records/azxmd-8wy09', 'parent_html': 'https://127.0.0.1:5000/records/azxmd-8wy09', 'self_iiif_manifest': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/manifest', 'self_iiif_sequence': 'https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/sequence/default', 'files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files', 'media_files': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files', 'archive': 'https://127.0.0.1:5000/api/records/mj154-z9j55/files-archive', 'archive_media': 'https://127.0.0.1:5000/api/records/mj154-z9j55/media-files-archive', 'latest': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions/latest', 'latest_html': 'https://127.0.0.1:5000/records/mj154-z9j55/latest', 'draft': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft', 'versions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/versions', 'access_links': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/links', 'access_grants': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/grants', 'access_users': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/users', 'access_groups': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/groups', 'access_request': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access/request', 'access': 'https://127.0.0.1:5000/api/records/mj154-z9j55/access', 'reserve_doi': 'https://127.0.0.1:5000/api/records/mj154-z9j55/draft/pids/doi', 'communities': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities', 'communities-suggestions': 'https://127.0.0.1:5000/api/records/mj154-z9j55/communities-suggestions', 'requests': 'https://127.0.0.1:5000/api/records/mj154-z9j55/requests'}, 'revision_id': 3, 'parent': {'id': 'azxmd-8wy09', 'access': {'owned_by': {'user': '2'}, 'settings': {'allow_user_requests': False, 'allow_guest_requests': False, 'accept_conditions_text': None, 'secret_link_expiration': 0}}, 'communities': {}, 'pids': {}}, 'versions': {'is_latest': True, 'index': 1}, 'is_published': True, 'is_draft': False, 'pids': {'oai': {'identifier': 'oai:my-site.com:mj154-z9j55', 'provider': 'oai'}}, 'metadata': {'resource_type': {'id': 'image', 'title': {'de': 'Bild', 'en': 'Image', 'sv': 'Bild'}}, 'creators': [{'person_or_org': {'type': 'personal', 'name': 'Patel, Thomas', 'given_name': 'Thomas', 'family_name': 'Patel', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Jones, Carla', 'given_name': 'Carla', 'family_name': 'Jones', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'contactperson', 'title': {'de': 'Kontaktperson', 'en': 'Contact person', 'sv': 'Kontaktperson'}}}, {'person_or_org': {'type': 'personal', 'name': 'Pierce, Christopher', 'given_name': 'Christopher', 'family_name': 'Pierce', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'other', 'title': {'de': 'Andere', 'en': 'Other', 'sv': 'Övriga'}}}, {'person_or_org': {'type': 'personal', 'name': 'Martinez, Michael', 'given_name': 'Michael', 'family_name': 'Martinez', 'identifiers': [{'identifier': '0000-0002-1825-0097', 'scheme': 'orcid'}]}, 'role': {'id': 'datacollector', 'title': {'de': 'DatensammlerIn', 'en': 'Data collector', 'sv': 'Datainsamlare'}}}], 'title': "Stevenson-Jenkins's gallery", 'additional_titles': [{'title': 'a research data management platform', 'type': {'id': 'alternative-title', 'title': {'de': 'Alternativer Titel', 'en': 'Alternative title', 'sv': 'Alternativ titel'}}, 'lang': {'id': 'eng', 'title': {'en': 'English'}}}, {'title': "Smith-Contreras's gallery", 'type': {'id': ...

# %% [markdown]
#  Testing with Sample Metadata
# To verify metadata output:
#
# Use the Invenio web interface or CLI to add a sample record.
# Fetch that record programmatically:

# %%
import requests
import json

# Base API endpoint
base_url = "https://127.0.0.1:5000/api/records/"

# Specific record ID
record_id = "mj154-z9j55" 

# Access token for authentication
headers = {
    "Authorization": "Bearer j66RscNftV77c28t3eNidKkkKPPQpgsLnXLcPXEHoPGxoD8FTxwtBcMFc0fC",
    "Accept": "application/vnd.inveniordm.v1+json"  # Request detailed metadata
}

# Fetch metadata
response = requests.get(f"{base_url}{record_id}", headers=headers, verify=False)

if response.status_code == 200:
    record = response.json()
    print("Detailed Metadata:")
    metadata = record.get('metadata', {})
    print(json.dumps(metadata, indent=4, ensure_ascii=False))
    print('metadata keys')
    for key in metadata.keys(): print (key)
else:
    print(f"Failed to fetch metadata. Status code: {response.status_code}")
    print(response.text)
# Out:
# Detailed Metadata:
# {
#     "resource_type": {
#         "id": "image",
#         "title": {
#             "de": "Bild",
#             "en": "Image",
#             "sv": "Bild"
#         }
#     },
#     "creators": [
#         {
#             "person_or_org": {
#                 "type": "personal",
#                 "name": "Patel, Thomas",
#                 "given_name": "Thomas",
#                 "family_name": "Patel",
#                 "identifiers": [
#                     {
#                         "identifier": "0000-0002-1825-0097",
#                         "scheme": "orcid"
#                     }
#                 ]
#             },
#             "role": {
#                 "id": "other",
#                 "title": {
#                     "de": "Andere",
#                     "en": "Other",
#                     "sv": "Övriga"
#                 }
#             }
#         },
#         {
#             "person_or_org": {
#                 "type": "personal",
#                 "name": "Jones, Carla",
#                 "given_name": "Carla",
#                 "family_name": "Jones",
#                 "identifiers": [
#                     {
#                         "identifier": "0000-0002-1825-0097",
#                         "scheme": "orcid"
#                     }
#                 ]
#             },
#             "role": {
#                 "id": "contactperson",
#                 "title": {
#                     "de": "Kontaktperson",
#                     "en": "Contact person",
#                     "sv": "Kontaktperson"
#                 }
#             }
#         },
#         {
#             "person_or_org": {
#                 "type": "personal",
#                 "name": "Pierce, Christopher",
#                 "given_name": "Christopher",
#                 "family_name": "Pierce",
#                 "identifiers": [
#                     {
#                         "identifier": "0000-0002-1825-0097",
#                         "scheme": "orcid"
#                     }
#                 ]
#             },
#             "role": {
#                 "id": "other",
#                 "title": {
#                     "de": "Andere",
#                     "en": "Other",
#                     "sv": "Övriga"
#                 }
#             }
#         },
#         {
#             "person_or_org": {
#                 "type": "personal",
#                 "name": "Martinez, Michael",
#                 "given_name": "Michael",
#                 "family_name": "Martinez",
#                 "identifiers": [
#                     {
#                         "identifier": "0000-0002-1825-0097",
#                         "scheme": "orcid"
#                     }
#                 ]
#             },
#             "role": {
#                 "id": "datacollector",
#                 "title": {
#                     "de": "DatensammlerIn",
#                     "en": "Data collector",
#                     "sv": "Datainsamlare"
#                 }
#             }
#         }
#     ],
#     "title": "Stevenson-Jenkins's gallery",
#     "additional_titles": [
#         {
#             "title": "a research data management platform",
#             "type": {
#                 "id": "alternative-title",
#                 "title": {
#                     "de": "Alternativer Titel",
#                     "en": "Alternative title",
#                     "sv": "Alternativ titel"
#                 }
#             },
#             "lang": {
#                 "id": "eng",
#                 "title": {
#                     "en": "English"
#                 }
#             }
#         },
#         {
#             "title": "Smith-Contreras's gallery",
#             "type": {
#                 "id": "alternative-title",
#                 "title": {
#                     "de": "Alternativer Titel",
#                     "en": "Alternative title",
#                     "sv": "Alternativ titel"
#                 }
#             },
#             "lang": {
#                 "id": "aah",
#                 "title": {
#                     "en": "Abu' Arapesh"
#                 }
#             }
#         }
#     ],
#     "publisher": "InvenioRDM",
#     "publication_date": "1971/1987",
#     "contributors": [
#         {
#             "person_or_org": {
#                 "type": "personal",
#                 "name": "Collins, Danielle",
#                 "given_name": "Danielle",
#                 "family_name": "Collins"
#             },
#             "role": {
#                 "id": "contactperson",
#                 "title": {
#                     "de": "Kontaktperson",
#                     "en": "Contact person",
#                     "sv": "Kontaktperson"
#                 }
#             }
#         },
#         {
#             "person_or_org": {
#                 "type": "personal",
#                 "name": "Norris, Stacey",
#                 "given_name": "Stacey",
#                 "family_name": "Norris"
#             },
#             "role": {
#                 "id": "other",
#                 "title": {
#                     "de": "Andere",
#                     "en": "Other",
#                     "sv": "Övriga"
#                 }
#             }
#         },
#         {
#             "person_or_org": {
#                 "type": "personal",
#                 "name": "Peterson, Jennifer",
#                 "given_name": "Jennifer",
#                 "family_name": "Peterson"
#             },
#             "role": {
#                 "id": "contactperson",
#                 "title": {
#                     "de": "Kontaktperson",
#                     "en": "Contact person",
#                     "sv": "Kontaktperson"
#                 }
#             }
#         }
#     ],
#     "languages": [
#         {
#             "id": "aah",
#             "title": {
#                 "en": "Abu' Arapesh"
#             }
#         }
#     ],
#     "identifiers": [
#         {
#             "identifier": "ark:/123/456",
#             "scheme": "ark"
#         }
#     ],
#     "related_identifiers": [
#         {
#             "identifier": "10.9999/rdm.9999988",
#             "scheme": "doi",
#             "relation_type": {
#                 "id": "cites",
#                 "title": {
#                     "de": "Zitiert",
#                     "en": "Cites",
#                     "sv": "Citerar"
#                 }
#             },
#             "resource_type": {
#                 "id": "publication",
#                 "title": {
#                     "de": "Publikation",
#                     "en": "Publication",
#                     "sv": "Publikation"
#                 }
#             }
#         }
#     ],
#     "sizes": [
#         "11 pages"
#     ],
#     "formats": [
#         "application/pdf"
#     ],
#     "version": "v0.0.1",
#     "description": "Member lawyer inside travel agreement increase heart. How various laugh professional same arm reason. Hair report true.\nGrowth difficult Mrs product else. Experience start election financial wish. Television first seem others. Certainly debate and Republican water opportunity individual.\nIndicate enjoy family she determine. Person ahead even agency more.\nAs save medical. Change major ahead bar. Few herself these choice newspaper.\nRealize interest read. Ability during defense conference push pay week teach.\nTable tonight suggest best realize onto. Anyone easy radio key fire.\nNearly remember play today. Worker resource responsibility smile clearly time sport. Writer heart traditional foreign effect crime practice.\nHappy collection student allow. Type draw during reveal culture area author contain. Value near fish operation return wide live pick.\nStart when either opportunity page ok. Bar not agree whether compare care.\nSay or drug sense dinner ability forward. Present since would yard. Five yes control may somebody resource. This north ever necessary various Mrs city.\nPrice space fear dark. Nation may name paper several deep production. Realize research moment arm.\nPurpose determine their strong official area. Raise four protect. Develop concern author clear three economy.\nIndustry ask radio since exist. Sign heavy long argue.\nLikely call throw list research. Far speak be although truth gun score. Board bit reflect candidate.\nLess face thousand key power guess week hit. Capital subject past. Control process lead various.\nIts become social reduce mission. One eye newspaper most.\nLeader easy member baby cup response suggest. Society management human movie really development someone remember.\nIssue mention view news. Tv somebody trial music image current fall. Ball do bar environmental able can drug reduce. Dark join soon which Mrs affect.\nHere consumer visit use.\nSkill project town station resource court per. System standard that open into. Management step many feeling garden teacher nothing.\nHope everybody think.\nThe perhaps court.\nDeep pull stuff free lot soldier. Week popular response coach note require tax.\nFact pull give art ever. Magazine suffer people lot detail.\nUnder activity research under. Measure majority factor past anything.\nNothing line culture save car yard gas little. Gun bed now name east man these. Minute international official Mrs general hand consider daughter.\nHave year now development concern police go. Million floor dark such financial image friend.\nPay still fine out investment thus. True shoulder significant.\nLeast director charge north relationship goal newspaper. Who wife detail themselves election method. Technology billion why entire reflect.\nDecision bill simply pretty budget. Board cup technology also.\nNorth though south kitchen major catch. Clearly remember learn conference. Course in necessary each drive.\nOften wind argue may. Build ago enough worker.",
#     "additional_descriptions": [
#         {
#             "description": "Prepare ever like feeling indicate. View senior arm purpose. Force both PM data form put person him.\nStar skill ground nature. Special mention career end section fast color form.",
#             "type": {
#                 "id": "methods",
#                 "title": {
#                     "de": "Methoden",
#                     "en": "Methods",
#                     "sv": "Metoder"
#                 }
#             }
#         },
#         {
#             "description": "Again high head old own other paper. Next service citizen water.\nWill both business about people.",
#             "type": {
#                 "id": "table-of-contents",
#                 "title": {
#                     "de": "Inhaltsverzeichnis",
#                     "en": "Table of contents",
#                     "sv": "Innehållsförteckning"
#                 }
#             }
#         }
#     ],
#     "funding": [
#         {
#             "funder": {
#                 "id": "00k4n6c32",
#                 "name": "European Commission"
#             }
#         }
#     ],
#     "references": [
#         {
#             "identifier": "0000000114559647",
#             "scheme": "isni",
#             "reference": "Reference to something et al."
#         }
#     ]
# }
# metadata keys
# resource_type
# creators
# title
# additional_titles
# publisher
# publication_date
# contributors
# languages
# identifiers
# related_identifiers
# sizes
# formats
# version
# description
# additional_descriptions
# funding
# references

# %%
import requests
import json

# Base API endpoint
base_url = "https://127.0.0.1:5000/api/records/"

# Specific record ID
record_id = "mj154-z9j55" 

# Access token for authentication
headers = {
    "Authorization": "Bearer j66RscNftV77c28t3eNidKkkKPPQpgsLnXLcPXEHoPGxoD8FTxwtBcMFc0fC",
    "Accept": "application/vnd.inveniordm.v1+json"  # Request detailed metadata
}

# Fetch metadata
response = requests.get(f"{base_url}{record_id}", headers=headers, verify=False)

if response.status_code == 200:
    record = response.json()
    print("Record:")
    # metadata = record.get('metadata', {})
    print(json.dumps(record, indent=4, ensure_ascii=False))
    # print(metadata)
else:
    print(f"Failed to fetch metadata. Status code: {response.status_code}")
    print(response.text)
# Out:
# Record:
# {
#     "id": "mj154-z9j55",
#     "created": "2025-01-19T15:30:03.367594+00:00",
#     "updated": "2025-01-19T15:30:03.596920+00:00",
#     "links": {
#         "self": "https://127.0.0.1:5000/api/records/mj154-z9j55",
#         "self_html": "https://127.0.0.1:5000/records/mj154-z9j55",
#         "parent": "https://127.0.0.1:5000/api/records/azxmd-8wy09",
#         "parent_html": "https://127.0.0.1:5000/records/azxmd-8wy09",
#         "self_iiif_manifest": "https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/manifest",
#         "self_iiif_sequence": "https://127.0.0.1:5000/api/iiif/record:mj154-z9j55/sequence/default",
#         "files": "https://127.0.0.1:5000/api/records/mj154-z9j55/files",
#         "media_files": "https://127.0.0.1:5000/api/records/mj154-z9j55/media-files",
#         "archive": "https://127.0.0.1:5000/api/records/mj154-z9j55/files-archive",
#         "archive_media": "https://127.0.0.1:5000/api/records/mj154-z9j55/media-files-archive",
#         "latest": "https://127.0.0.1:5000/api/records/mj154-z9j55/versions/latest",
#         "latest_html": "https://127.0.0.1:5000/records/mj154-z9j55/latest",
#         "draft": "https://127.0.0.1:5000/api/records/mj154-z9j55/draft",
#         "versions": "https://127.0.0.1:5000/api/records/mj154-z9j55/versions",
#         "access_links": "https://127.0.0.1:5000/api/records/mj154-z9j55/access/links",
#         "access_grants": "https://127.0.0.1:5000/api/records/mj154-z9j55/access/grants",
#         "access_users": "https://127.0.0.1:5000/api/records/mj154-z9j55/access/users",
#         "access_groups": "https://127.0.0.1:5000/api/records/mj154-z9j55/access/groups",
#         "access_request": "https://127.0.0.1:5000/api/records/mj154-z9j55/access/request",
#         "access": "https://127.0.0.1:5000/api/records/mj154-z9j55/access",
#         "reserve_doi": "https://127.0.0.1:5000/api/records/mj154-z9j55/draft/pids/doi",
#         "communities": "https://127.0.0.1:5000/api/records/mj154-z9j55/communities",
#         "communities-suggestions": "https://127.0.0.1:5000/api/records/mj154-z9j55/communities-suggestions",
#         "requests": "https://127.0.0.1:5000/api/records/mj154-z9j55/requests"
#     },
#     "revision_id": 3,
#     "parent": {
#         "id": "azxmd-8wy09",
#         "access": {
#             "owned_by": {
#                 "user": "2"
#             },
#             "settings": {
#                 "allow_user_requests": false,
#                 "allow_guest_requests": false,
#                 "accept_conditions_text": null,
#                 "secret_link_expiration": 0
#             }
#         },
#         "communities": {},
#         "pids": {}
#     },
#     "versions": {
#         "is_latest": true,
#         "index": 1
#     },
#     "is_published": true,
#     "is_draft": false,
#     "pids": {
#         "oai": {
#             "identifier": "oai:my-site.com:mj154-z9j55",
#             "provider": "oai"
#         }
#     },
#     "metadata": {
#         "resource_type": {
#             "id": "image",
#             "title": {
#                 "de": "Bild",
#                 "en": "Image",
#                 "sv": "Bild"
#             }
#         },
#         "creators": [
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Patel, Thomas",
#                     "given_name": "Thomas",
#                     "family_name": "Patel",
#                     "identifiers": [
#                         {
#                             "identifier": "0000-0002-1825-0097",
#                             "scheme": "orcid"
#                         }
#                     ]
#                 },
#                 "role": {
#                     "id": "other",
#                     "title": {
#                         "de": "Andere",
#                         "en": "Other",
#                         "sv": "Övriga"
#                     }
#                 }
#             },
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Jones, Carla",
#                     "given_name": "Carla",
#                     "family_name": "Jones",
#                     "identifiers": [
#                         {
#                             "identifier": "0000-0002-1825-0097",
#                             "scheme": "orcid"
#                         }
#                     ]
#                 },
#                 "role": {
#                     "id": "contactperson",
#                     "title": {
#                         "de": "Kontaktperson",
#                         "en": "Contact person",
#                         "sv": "Kontaktperson"
#                     }
#                 }
#             },
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Pierce, Christopher",
#                     "given_name": "Christopher",
#                     "family_name": "Pierce",
#                     "identifiers": [
#                         {
#                             "identifier": "0000-0002-1825-0097",
#                             "scheme": "orcid"
#                         }
#                     ]
#                 },
#                 "role": {
#                     "id": "other",
#                     "title": {
#                         "de": "Andere",
#                         "en": "Other",
#                         "sv": "Övriga"
#                     }
#                 }
#             },
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Martinez, Michael",
#                     "given_name": "Michael",
#                     "family_name": "Martinez",
#                     "identifiers": [
#                         {
#                             "identifier": "0000-0002-1825-0097",
#                             "scheme": "orcid"
#                         }
#                     ]
#                 },
#                 "role": {
#                     "id": "datacollector",
#                     "title": {
#                         "de": "DatensammlerIn",
#                         "en": "Data collector",
#                         "sv": "Datainsamlare"
#                     }
#                 }
#             }
#         ],
#         "title": "Stevenson-Jenkins's gallery",
#         "additional_titles": [
#             {
#                 "title": "a research data management platform",
#                 "type": {
#                     "id": "alternative-title",
#                     "title": {
#                         "de": "Alternativer Titel",
#                         "en": "Alternative title",
#                         "sv": "Alternativ titel"
#                     }
#                 },
#                 "lang": {
#                     "id": "eng",
#                     "title": {
#                         "en": "English"
#                     }
#                 }
#             },
#             {
#                 "title": "Smith-Contreras's gallery",
#                 "type": {
#                     "id": "alternative-title",
#                     "title": {
#                         "de": "Alternativer Titel",
#                         "en": "Alternative title",
#                         "sv": "Alternativ titel"
#                     }
#                 },
#                 "lang": {
#                     "id": "aah",
#                     "title": {
#                         "en": "Abu' Arapesh"
#                     }
#                 }
#             }
#         ],
#         "publisher": "InvenioRDM",
#         "publication_date": "1971/1987",
#         "contributors": [
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Collins, Danielle",
#                     "given_name": "Danielle",
#                     "family_name": "Collins"
#                 },
#                 "role": {
#                     "id": "contactperson",
#                     "title": {
#                         "de": "Kontaktperson",
#                         "en": "Contact person",
#                         "sv": "Kontaktperson"
#                     }
#                 }
#             },
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Norris, Stacey",
#                     "given_name": "Stacey",
#                     "family_name": "Norris"
#                 },
#                 "role": {
#                     "id": "other",
#                     "title": {
#                         "de": "Andere",
#                         "en": "Other",
#                         "sv": "Övriga"
#                     }
#                 }
#             },
#             {
#                 "person_or_org": {
#                     "type": "personal",
#                     "name": "Peterson, Jennifer",
#                     "given_name": "Jennifer",
#                     "family_name": "Peterson"
#                 },
#                 "role": {
#                     "id": "contactperson",
#                     "title": {
#                         "de": "Kontaktperson",
#                         "en": "Contact person",
#                         "sv": "Kontaktperson"
#                     }
#                 }
#             }
#         ],
#         "languages": [
#             {
#                 "id": "aah",
#                 "title": {
#                     "en": "Abu' Arapesh"
#                 }
#             }
#         ],
#         "identifiers": [
#             {
#                 "identifier": "ark:/123/456",
#                 "scheme": "ark"
#             }
#         ],
#         "related_identifiers": [
#             {
#                 "identifier": "10.9999/rdm.9999988",
#                 "scheme": "doi",
#                 "relation_type": {
#                     "id": "cites",
#                     "title": {
#                         "de": "Zitiert",
#                         "en": "Cites",
#                         "sv": "Citerar"
#                     }
#                 },
#                 "resource_type": {
#                     "id": "publication",
#                     "title": {
#                         "de": "Publikation",
#                         "en": "Publication",
#                         "sv": "Publikation"
#                     }
#                 }
#             }
#         ],
#         "sizes": [
#             "11 pages"
#         ],
#         "formats": [
#             "application/pdf"
#         ],
#         "version": "v0.0.1",
#         "description": "Member lawyer inside travel agreement increase heart. How various laugh professional same arm reason. Hair report true.\nGrowth difficult Mrs product else. Experience start election financial wish. Television first seem others. Certainly debate and Republican water opportunity individual.\nIndicate enjoy family she determine. Person ahead even agency more.\nAs save medical. Change major ahead bar. Few herself these choice newspaper.\nRealize interest read. Ability during defense conference push pay week teach.\nTable tonight suggest best realize onto. Anyone easy radio key fire.\nNearly remember play today. Worker resource responsibility smile clearly time sport. Writer heart traditional foreign effect crime practice.\nHappy collection student allow. Type draw during reveal culture area author contain. Value near fish operation return wide live pick.\nStart when either opportunity page ok. Bar not agree whether compare care.\nSay or drug sense dinner ability forward. Present since would yard. Five yes control may somebody resource. This north ever necessary various Mrs city.\nPrice space fear dark. Nation may name paper several deep production. Realize research moment arm.\nPurpose determine their strong official area. Raise four protect. Develop concern author clear three economy.\nIndustry ask radio since exist. Sign heavy long argue.\nLikely call throw list research. Far speak be although truth gun score. Board bit reflect candidate.\nLess face thousand key power guess week hit. Capital subject past. Control process lead various.\nIts become social reduce mission. One eye newspaper most.\nLeader easy member baby cup response suggest. Society management human movie really development someone remember.\nIssue mention view news. Tv somebody trial music image current fall. Ball do bar environmental able can drug reduce. Dark join soon which Mrs affect.\nHere consumer visit use.\nSkill project town station resource court per. System standard that open into. Management step many feeling garden teacher nothing.\nHope everybody think.\nThe perhaps court.\nDeep pull stuff free lot soldier. Week popular response coach note require tax.\nFact pull give art ever. Magazine suffer people lot detail.\nUnder activity research under. Measure majority factor past anything.\nNothing line culture save car yard gas little. Gun bed now name east man these. Minute international official Mrs general hand consider daughter.\nHave year now development concern police go. Million floor dark such financial image friend.\nPay still fine out investment thus. True shoulder significant.\nLeast director charge north relationship goal newspaper. Who wife detail themselves election method. Technology billion why entire reflect.\nDecision bill simply pretty budget. Board cup technology also.\nNorth though south kitchen major catch. Clearly remember learn conference. Course in necessary each drive.\nOften wind argue may. Build ago enough worker.",
#         "additional_descriptions": [
#             {
#                 "description": "Prepare ever like feeling indicate. View senior arm purpose. Force both PM data form put person him.\nStar skill ground nature. Special mention career end section fast color form.",
#                 "type": {
#                     "id": "methods",
#                     "title": {
#                         "de": "Methoden",
#                         "en": "Methods",
#                         "sv": "Metoder"
#                     }
#                 }
#             },
#             {
#                 "description": "Again high head old own other paper. Next service citizen water.\nWill both business about people.",
#                 "type": {
#                     "id": "table-of-contents",
#                     "title": {
#                         "de": "Inhaltsverzeichnis",
#                         "en": "Table of contents",
#                         "sv": "Innehållsförteckning"
#                     }
#                 }
#             }
#         ],
#         "funding": [
#             {
#                 "funder": {
#                     "id": "00k4n6c32",
#                     "name": "European Commission"
#                 }
#             }
#         ],
#         "references": [
#             {
#                 "identifier": "0000000114559647",
#                 "scheme": "isni",
#                 "reference": "Reference to something et al."
#             }
#         ]
#     },
#     "custom_fields": {},
#     "access": {
#         "record": "public",
#         "files": "public",
#         "embargo": {
#             "active": false,
#             "reason": null
#         },
#         "status": "metadata-only"
#     },
#     "files": {
#         "enabled": false,
#         "order": [],
#         "count": 0,
#         "total_bytes": 0,
#         "entries": {}
#     },
#     "media_files": {
#         "enabled": false,
#         "order": [],
#         "count": 0,
#         "total_bytes": 0,
#         "entries": {}
#     },
#     "status": "published",
#     "deletion_status": {
#         "is_deleted": false,
#         "status": "P"
#     },
#     "stats": {
#         "this_version": {
#             "views": 0,
#             "unique_views": 0,
#             "downloads": 0,
#             "unique_downloads": 0,
#             "data_volume": 0.0
#         },
#         "all_versions": {
#             "views": 0,
#             "unique_views": 0,
#             "downloads": 0,
#             "unique_downloads": 0,
#             "data_volume": 0.0
#         }
#     },
#     "ui": {
#         "publication_date_l10n_medium": "1971 – 1987",
#         "publication_date_l10n_long": "1971 – 1987",
#         "created_date_l10n_long": "January 19, 2025",
#         "updated_date_l10n_long": "January 19, 2025",
#         "resource_type": {
#             "id": "image",
#             "title_l10n": "Image"
#         },
#         "additional_titles": [
#             {
#                 "title": "a research data management platform",
#                 "type": {
#                     "id": "alternative-title",
#                     "title_l10n": "Alternative title"
#                 },
#                 "lang": {
#                     "id": "eng",
#                     "title_l10n": "English"
#                 }
#             },
#             {
#                 "title": "Smith-Contreras's gallery",
#                 "type": {
#                     "id": "alternative-title",
#                     "title_l10n": "Alternative title"
#                 },
#                 "lang": {
#                     "id": "aah",
#                     "title_l10n": "Abu' Arapesh"
#                 }
#             }
#         ],
#         "custom_fields": {},
#         "access_status": {
#             "id": "metadata-only",
#             "title_l10n": "Metadata-only",
#             "description_l10n": "No files are available for this record.",
#             "icon": "tag",
#             "embargo_date_l10n": null,
#             "message_class": ""
#         },
#         "creators": {
#             "creators": [
#                 {
#                     "person_or_org": {
#                         "type": "personal",
#                         "name": "Patel, Thomas",
#                         "given_name": "Thomas",
#                         "family_name": "Patel",
#                         "identifiers": [
#                             {
#                                 "identifier": "0000-0002-1825-0097",
#                                 "scheme": "orcid"
#                             }
#                         ]
#                     },
#                     "role": {
#                         "id": "other",
#                         "title": "Other"
#                     }
#                 },
#                 {
#                     "person_or_org": {
#                         "type": "personal",
#                         "name": "Jones, Carla",
#                         "given_name": "Carla",
#                         "family_name": "Jones",
#                         "identifiers": [
#                             {
#                                 "identifier": "0000-0002-1825-0097",
#                                 "scheme": "orcid"
#                             }
#                         ]
#                     },
#                     "role": {
#                         "id": "contactperson",
#                         "title": "Contact person"
#                     }
#                 },
#                 {
#                     "person_or_org": {
#                         "type": "personal",
#                         "name": "Pierce, Christopher",
#                         "given_name": "Christopher",
#                         "family_name": "Pierce",
#                         "identifiers": [
#                             {
#                                 "identifier": "0000-0002-1825-0097",
#                                 "scheme": "orcid"
#                             }
#                         ]
#                     },
#                     "role": {
#                         "id": "other",
#                         "title": "Other"
#                     }
#                 },
#                 {
#                     "person_or_org": {
#                         "type": "personal",
#                         "name": "Martinez, Michael",
#                         "given_name": "Michael",
#                         "family_name": "Martinez",
#                         "identifiers": [
#                             {
#                                 "identifier": "0000-0002-1825-0097",
#                                 "scheme": "orcid"
#                             }
#                         ]
#                     },
#                     "role": {
#                         "id": "datacollector",
#                         "title": "Data collector"
#                     }
#                 }
#             ],
#             "affiliations": []
#         },
#         "contributors": {
#             "contributors": [
#                 {
#                     "person_or_org": {
#                         "type": "personal",
#                         "name": "Collins, Danielle",
#                         "given_name": "Danielle",
#                         "family_name": "Collins"
#                     },
#                     "role": {
#                         "id": "contactperson",
#                         "title": "Contact person"
#                     }
#                 },
#                 {
#                     "person_or_org": {
#                         "type": "personal",
#                         "name": "Norris, Stacey",
#                         "given_name": "Stacey",
#                         "family_name": "Norris"
#                     },
#                     "role": {
#                         "id": "other",
#                         "title": "Other"
#                     }
#                 },
#                 {
#                     "person_or_org": {
#                         "type": "personal",
#                         "name": "Peterson, Jennifer",
#                         "given_name": "Jennifer",
#                         "family_name": "Peterson"
#                     },
#                     "role": {
#                         "id": "contactperson",
#                         "title": "Contact person"
#                     }
#                 }
#             ],
#             "affiliations": []
#         },
#         "languages": [
#             {
#                 "id": "aah",
#                 "title_l10n": "Abu' Arapesh"
#             }
#         ],
#         "description_stripped": "Member lawyer inside travel agreement increase heart. How various laugh professional same arm reason. Hair report true.\nGrowth difficult Mrs product else. Experience start election financial wish. Television first seem others. Certainly debate and Republican water opportunity individual.\nIndicate enjoy family she determine. Person ahead even agency more.\nAs save medical. Change major ahead bar. Few herself these choice newspaper.\nRealize interest read. Ability during defense conference push pay week teach.\nTable tonight suggest best realize onto. Anyone easy radio key fire.\nNearly remember play today. Worker resource responsibility smile clearly time sport. Writer heart traditional foreign effect crime practice.\nHappy collection student allow. Type draw during reveal culture area author contain. Value near fish operation return wide live pick.\nStart when either opportunity page ok. Bar not agree whether compare care.\nSay or drug sense dinner ability forward. Present since would yard. Five yes control may somebody resource. This north ever necessary various Mrs city.\nPrice space fear dark. Nation may name paper several deep production. Realize research moment arm.\nPurpose determine their strong official area. Raise four protect. Develop concern author clear three economy.\nIndustry ask radio since exist. Sign heavy long argue.\nLikely call throw list research. Far speak be although truth gun score. Board bit reflect candidate.\nLess face thousand key power guess week hit. Capital subject past. Control process lead various.\nIts become social reduce mission. One eye newspaper most.\nLeader easy member baby cup response suggest. Society management human movie really development someone remember.\nIssue mention view news. Tv somebody trial music image current fall. Ball do bar environmental able can drug reduce. Dark join soon which Mrs affect.\nHere consumer visit use.\nSkill project town station resource court per. System standard that open into. Management step many feeling garden teacher nothing.\nHope everybody think.\nThe perhaps court.\nDeep pull stuff free lot soldier. Week popular response coach note require tax.\nFact pull give art ever. Magazine suffer people lot detail.\nUnder activity research under. Measure majority factor past anything.\nNothing line culture save car yard gas little. Gun bed now name east man these. Minute international official Mrs general hand consider daughter.\nHave year now development concern police go. Million floor dark such financial image friend.\nPay still fine out investment thus. True shoulder significant.\nLeast director charge north relationship goal newspaper. Who wife detail themselves election method. Technology billion why entire reflect.\nDecision bill simply pretty budget. Board cup technology also.\nNorth though south kitchen major catch. Clearly remember learn conference. Course in necessary each drive.\nOften wind argue may. Build ago enough worker.",
#         "version": "v0.0.1",
#         "related_identifiers": [
#             {
#                 "identifier": "10.9999/rdm.9999988",
#                 "relation_type": {
#                     "id": "cites",
#                     "title_l10n": "Cites"
#                 },
#                 "scheme": "doi",
#                 "resource_type": {
#                     "id": "publication",
#                     "title_l10n": "Publication"
#                 }
#             }
#         ],
#         "additional_descriptions": [
#             {
#                 "description": "Prepare ever like feeling indicate. View senior arm purpose. Force both PM data form put person him.\nStar skill ground nature. Special mention career end section fast color form.",
#                 "type": {
#                     "id": "methods",
#                     "title_l10n": "Methods"
#                 }
#             },
#             {
#                 "description": "Again high head old own other paper. Next service citizen water.\nWill both business about people.",
#                 "type": {
#                     "id": "table-of-contents",
#                     "title_l10n": "Table of contents"
#                 }
#             }
#         ],
#         "is_draft": false,
#         "funding": [
#             {
#                 "funder": {
#                     "id": "00k4n6c32",
#                     "name": "European Commission"
#                 }
#             }
#         ]
#     }
# }
